# %%
import pandas as pd

df = pd.read_excel("permim.xlsx")
df
# Out:
#    Age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
x =df["Age"]

# %%
y=df["premium"]

# %%
x
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
y
# Out:
# 0    18000
# 1    32000
# 2    40000
# 3    47000
# 4    55000
# Name: premium, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print(f"{x_train}\n",y_train)
# Out:
# 4    45
# 3    40
# 0    25
# Name: Age, dtype: int64
#  4    55000
# 3    47000
# 0    18000
# Name: premium, dtype: int64

# %%
print(f"{x_test}\n",y_test)
# Out:
# 1    30
# 2    35
# Name: Age, dtype: int64
#  1    32000
# 2    40000
# Name: premium, dtype: int64
